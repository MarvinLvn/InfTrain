# %%
#from Marvin notebook

# %%
# Read item file
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
lang="fr" #en
ITEM_PATH = os.path.join("/gpfsscratch/rech/cfs/commun/cv21_ABX/raw_dataset",lang,lang+".item")
df = pd.read_csv(ITEM_PATH, sep=" ")
df['spk'] = df.apply(lambda x : x['speaker'][0:5], axis=1)
nb_phones = len(np.unique(df["#phone"]))


print("%d different phones found" % nb_phones)
# Out:
# 35 different phones found

# %%
print(len(np.unique(df["spk"])))
print(len(np.unique(df["speaker"])))
# Out:
# 24
# 24

# %%
df
# Out:
#                            #file  onset  offset #phone prev-phone next-phone  \
# 0       common_voice_fr_20306508   2.06    2.18     ou         dd         ei
# 1       common_voice_fr_20306508   2.18    2.28     ei         ou         ai
# 2       common_voice_fr_20306508   2.28    2.32     ai         ei         pp
# 3       common_voice_fr_20306508   2.32    2.39     pp         ai         rr
# 4       common_voice_fr_20306508   2.39    2.46     rr         pp         ai
# ...                          ...    ...     ...    ...        ...        ...
# 227449  common_voice_fr_20266111   3.88    3.94     rr         aa         ai
# 227450  common_voice_fr_20266111   3.94    4.06     ai         rr         kk
# 227451  common_voice_fr_20266111   4.06    4.21     kk         ai         ii
# 227452  common_voice_fr_20266111   4.21    4.27     ii         kk         pp
# 227453  common_voice_fr_20266111   4.27    4.39     pp         ii         ee
#
#                                                   speaker    spk
# 0       067d282a793fa4e9ffcfa6f6125ccf7f1329d48d579e38...  067d2
# 1       067d282a793fa4e9ffcfa6f6125ccf7f1329d48d579e38...  067d2
# 2       067d282a793fa4e9ffcfa6f6125ccf7f1329d48d579e38...  067d2
# 3       067d282a793fa4e9ffcfa6f6125ccf7f1329d48d579e38...  067d2
# 4       067d282a793fa4e9ffcfa6f6125ccf7f1329d48d579e38...  067d2
# ...                                                   ...    ...
# 227449  45d566f19dbef83f583f9db17f55954a5038febbe97dd2...  45d56
# 227450  45d566f19dbef83f583f9db17f55954a5038febbe97dd2...  45d56
# 227451  45d566f19dbef83f583f9db17f55954a5038febbe97dd2...  45d56
# 227452  45d566f19dbef83f583f9db17f55954a5038febbe97dd2...  45d56
# 227453  45d566f19dbef83f583f9db17f55954a5038febbe97dd2...  45d56
#
# [227454 rows x 8 columns]

# %%
phone_distrib = df["#phone"].value_counts()
plt.figure(figsize=(20,10))
plt.bar(phone_distrib.index, phone_distrib)
plt.xlabel("Phone")
plt.ylabel("Count")
plt.title("Center phone distribution in triphone items for French")
plt.xticks(rotation=45,fontsize=18)
plt.show()

# %%
spk_distrib = df["spk"].value_counts()
plt.figure(figsize=(20,10))
plt.bar(spk_distrib.index, spk_distrib)
plt.xlabel("Speaker")
plt.ylabel("Count")
plt.title("Speaker distribution for French")
plt.xticks(rotation=45,fontsize=18)
plt.show()

# %%
spk_distrib = df["speaker"].value_counts()
spk_distrib
# Out:
# 34b717f021f690d003ad5dd5ba8be174b87b033be6d6fcd04bf2abb3a967e5d7940bb5ce596f27b40a77d72b3853e7e45d4cad25b73ee5a6e370b4c2153a27f2    12176
# 97cff6dccbfa9de04e5bef3f4fc7b49700a9c9bc8f33054be9dc5af0bd11c0ad541ceb254051007c7460ef346e0605c49688412a10f789c896bb9f4ad89165ca     8467
# e2245777b14c8f4478b278e5445bb435880113722f4a11d0aade997ed687cdcd9f2ac57a6650e18cc4b52d267ebb8d0584eb4245a2e6c72069209a1bf1d6613e     8461
# 45d566f19dbef83f583f9db17f55954a5038febbe97dd2e7600de2942c3b2bc8d6d23b9c7f5dd1e58a869834cfa1a0f85be7425f37df53eb6dd938179d8640f7     8341
# 669affb9d334f7759037e1e181e06bf7764a8b337a385360d5615bbe003b286f0b2bdbc471f6c76c4576d5d145e57f37e17842b912ed349a1295c4b7033ff205     8253
# 592dc0785596d25f25089ff7c64f388cf2ea09adcb4418bd023b15e2337bb34250772b4f21ce193540025bf04a7d21edcaef9fae528be6e8c2ae61cce95a7b9d     8222
# 2e150680d4087ba6ae70ef0c6db87e61042163baaf75258801d3bc352d6f4103aea5630ad830678ed5ae16cfb0e869c7a9378d78af85a6bcb0dfdb89cd02b13e     7949
# Name: speaker, dtype: int64

# %%
print(phone_distrib)
# Out:
# ʁ     6269
# a     5047
# l     4854
# ɛ     4541
# s     4176
# i     3853
# t     3734
# ə     3597
# d     3530
# e     3096
# p     2651
# k     2609
# m     2537
# ɑ̃    2362
# n     2178
# ɔ     2033
# y     1903
# v     1786
# u     1455
# j     1424
# ɔ̃    1260
# f     1132
# b     1067
# ʒ      808
# e-     799
# o      744
# w      719
# a-     715
# z      667
# ɛ̃     648
# ɡ      608
# œ      481
# ø      434
# ʃ      417
# œ̃     322
# y-     212
# aː      60
# ɲ       39
# yː      34
# ɪ       33
# ɛː      19
# dʒ      15
# ʌ        9
# θ        8
# uː       5
# kː       4
# iː       4
# œː       3
# ɔː       3
# əʊ       2
# h        1
# ð        1
# Name: #phone, dtype: int64

# %%
lang="english"
ITEM_PATH = os.path.join(HOME,"data/zerospeech/zerospeech2017_dataset",lang,"1s/1s.item")
df = pd.read_csv(ITEM_PATH, sep=" ")

nb_phones = len(np.unique(df["#phone"]))

print("%d different phones found" % nb_phones)
phone_distrib = df["#phone"].value_counts()
plt.figure(figsize=(20,10))
plt.bar(phone_distrib.index, phone_distrib)
plt.xlabel("Phone")
plt.ylabel("Count")
plt.title("Center phone distribution in triphone items for English")
plt.xticks(rotation=45,fontsize=18)
plt.show()
# Out:
# 40 different phones found

# %%
print(phone_distrib)
# Out:
# ax    10313
# n      7878
# t      7257
# ih     5130
# d      5113
# s      4955
# r      4855
# l      4351
# iy     3477
# eh     3216
# dh     3091
# ae     3074
# m      3047
# k      2938
# ah     2741
# z      2671
# er     2630
# w      2151
# aa     2140
# v      2119
# p      2068
# hh     2004
# f      1994
# b      1818
# ay     1752
# ao     1745
# ey     1684
# ow     1293
# uw     1135
# ng     1079
# g       949
# sh      854
# aw      684
# y       647
# ch      612
# uh      511
# jh      499
# th      432
# oy      121
# zh       65
# Name: #phone, dtype: int64
