# %%
import json
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from glob import glob
#import seaborn as sns

# %%
#better and bigger plots inline
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 200 # 200 e.g. is really fine, but slower

# %%
HOME="/linkhome/rech/genini01/ucv88ce/"
eval_path=os.path.join(HOME,"projects/MultilingualCPC/experiments/eval/inftrain" )

# %%
def retrieve_scores(n_fam=32, size="200h", eval_path='/linkhome/rech/genini01/ucv88ce/projects/MultilingualCPC/experiments/eval/inftrain'):
    fam_dict={}

    #columns = fam_id, size, eval_lang, en_model, fr_model, bil_model, same, diff (same and diff are just the scores from tje model corresponding to th train and eval)
    #do average of within and across

    for fam in ["{}".format(str(x).zfill(2)) for x in range(n_fam-1)] :
        for eval_lang in ['english','french']:
            k = fam+"_"+eval_lang

            values = [fam, size, eval_lang]

            for model in ["EN","FR","EN+FR"]:
                path = os.path.join(eval_path,model,size,fam,"cpc_small/ABX","*",eval_lang, "ABX_scores.json")
                json_f = glob(path)
                if not json_f :
                    score = np.nan
                elif len(json_f) > 1:
                    raise ValueError("multiple checkpoint evaluated in {}".format(os.path.join(eval_path,"EN",size,fam,"cpc_small/ABX")))
                else:
                    with open(json_f[0], "r") as f:

                        scores = json.load(f)
                    score = np.mean([scores['within'],scores['across']]) * 100
                values.append(score)
                
                if model == "EN" and eval_lang == "english" :
                    same = score
                elif model == "EN" and eval_lang == "french" :
                    different = score
                elif model == "FR" and eval_lang == "french" :
                    same = score
                elif model == "FR" and eval_lang == "english" :
                    different = score
            
            values.append(same)
            values.append(different)
            fam_dict[k] = values

    df = pd.DataFrame.from_dict(fam_dict, orient='index', columns=["fam_id", "size", "eval_lang", "en_model", "fr_model", "bil_model", 'same', 'different'])
    return df

# %%
df_200h = retrieve_scores(size="200h")
df_100h = retrieve_scores(size="100h")
df = df_100h.append(df_200h, ignore_index=True)

# %%
df
# Out:
#     fam_id  size eval_lang   en_model   fr_model  bil_model       same  \
# 0       00  100h   english   8.388352   9.030477        NaN   8.388352
# 1       00  100h    french  12.360799  11.217824        NaN  11.217824
# 2       01  100h   english        NaN        NaN        NaN        NaN
# 3       01  100h    french        NaN  12.330139        NaN  12.330139
# 4       02  100h   english        NaN        NaN        NaN        NaN
# ..     ...   ...       ...        ...        ...        ...        ...
# 119     28  200h    french        NaN        NaN        NaN        NaN
# 120     29  200h   english        NaN        NaN        NaN        NaN
# 121     29  200h    french        NaN        NaN        NaN        NaN
# 122     30  200h   english        NaN        NaN        NaN        NaN
# 123     30  200h    french        NaN        NaN        NaN        NaN
#
#      different
# 0     9.030477
# 1    12.360799
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 119        NaN
# 120        NaN
# 121        NaN
# 122        NaN
# 123        NaN
#
# [124 rows x 8 columns]

# %%
boxplot = df_200h[['en_model', 'fr_model', 'bil_model', 'eval_lang']].boxplot(by='eval_lang', return_type='axes')
for bp in boxplot: 
    bp.set_ylabel('ABX error rate (in %)')
    bp.set_xlabel('Test Language')

# Here again just to show fundamental to look at it symmetrically as our test sets are not balancd (still looking into rules with XN)

# %%
boxplot = df[['size','en_model', 'fr_model',  'eval_lang']].boxplot(by='size', return_type='axes')
for bp in boxplot: 
    bp.set_ylabel('ABX error rate (in %)')
    bp.set_xlabel('# training hours')

# %%
#need to do it symmetrically (same vs different)
boxplot = df_200h[['same', 'different', 'bil_model']].boxplot(notch=True)
boxplot.set_ylabel('ABX error rate (in %)')
# need to find a way to compare bil 200h and same_100h and diff_100h
# here we are comparing total of 200h
# Out:
# Text(0, 0.5, 'ABX error rate (in %)')

# %%
#need to do it symmetrically (same vs different)
boxplot = df_200h[['same', 'different', 'bil_model','size']].boxplot(notch=False)
boxplot.set_ylabel('ABX error rate (in %)')
# need to find a way to compare bil 200h and same_100h and diff_100h
# here we are comparing total of 200h
# Out:
# Text(0, 0.5, 'ABX error rate (in %)')

# %%
df_200h.mean(numeric_only=True)
# Out:
# en_model      9.911833
# fr_model     10.407730
# bil_model    10.450665
# same          9.546356
# different    10.705344
# dtype: float64

# %%
np.mean([9.52668, 10.745492])
# Out:
# 10.136086
