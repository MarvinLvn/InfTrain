# %%
import json
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from glob import glob
#import seaborn as sns

# %%
#better and bigger plots inline
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 200 # 200 e.g. is really fine, but slower

# %%
HOME="/linkhome/rech/genini01/ucv88ce/"
eval_path=os.path.join(HOME,"projects/MultilingualCPC/experiments/eval/inftrain" )

# %%
def retrieve_scores(n_fam=32, size=200, eval_path='/linkhome/rech/genini01/ucv88ce/projects/MultilingualCPC/experiments/eval/inftrain'):
    fam_dict={}

    #columns = fam_id, size, eval_lang, en_model, fr_model, bil_model, same, diff (same and diff are just the scores from tje model corresponding to th train and eval)
    #do average of within and across

    for fam in ["{}".format(str(x).zfill(2)) for x in range(n_fam-1)] :
        for eval_lang in ['english','french']:
            k = fam+"_"+eval_lang

            values = [fam, int(size), eval_lang]

            for model in ["EN","FR","EN+FR"]:
                path = os.path.join(eval_path,model,str(size)+"h",fam,"cpc_small/ABX","*",eval_lang, "ABX_scores.json")
                json_f = glob(path)
                if not json_f :
                    score = np.nan
                elif len(json_f) > 1:
                    raise ValueError("multiple checkpoint evaluated in {}".format(os.path.join(eval_path,"EN",str(size)+"h",fam,"cpc_small/ABX")))
                else:
                    with open(json_f[0], "r") as f:

                        scores = json.load(f)
                    score = np.mean([scores['within'],scores['across']]) * 100
                values.append(score)
                
                if model == "EN" and eval_lang == "english" :
                    same = score
                elif model == "EN" and eval_lang == "french" :
                    different = score
                elif model == "FR" and eval_lang == "french" :
                    same = score
                elif model == "FR" and eval_lang == "english" :
                    different = score
            
            values.append(same)
            values.append(different)
            fam_dict[k] = values

    df = pd.DataFrame.from_dict(fam_dict, orient='index', columns=["fam_id", "size", "eval_lang", "en_model", "fr_model", "bil_model", 'same', 'different'])
    return df

# %%
from scipy import stats

def drop_outliers(df, columns = ["en_model", "fr_model", "bil_model"],z_thresh=3):
    excluded_fam = []
    for col in columns:
        z = np.abs(stats.zscore(df[col]))
        excluded_fam = excluded_fam + list(df[z >= 3]["fam_id"])
    
    excluded_fam = set(excluded_fam)
    return df[~df.fam_id.isin(excluded_fam)]

    
    # Drop (inplace) values set to be rejected
    return df.drop(df.index[~constrains], inplace=False)

# %%
df_200h = retrieve_scores(size="200")
df_100h = retrieve_scores(size="100")
df_400h = retrieve_scores(size="400")

# df = df_100h.append(df_200h, ignore_index=True).append(df_400h, ignore_index=True)

#remove rows where there are NAs, except if for 100h bil

# %%
#filter df
df_200h = retrieve_scores(size="200")
df_100h = retrieve_scores(size="100")
df_400h = retrieve_scores(size="400")

df_100h = df_100h[(df_100h["en_model"].notna()) & (df_100h["fr_model"].notna())]
df_200h = df_200h.dropna()
df_400h = df_400h.dropna()

df_200_400h = df_200h.append(df_400h, ignore_index=True)

df = df_200_400h.append(df_100h, ignore_index=True)
df_size = df.groupby(by="size").mean()

df_filt = drop_outliers(df)
df_filt_size = df_filtered.groupby(by="size").mean()

# %%
df
# Out:
#     fam_id  size eval_lang   en_model   fr_model  bil_model       same  \
# 0       00   200   english   8.008461  31.985082   8.173593   8.008461
# 1       00   200    french  11.925142  41.261384  11.617393  41.261384
# 2       01   200   english   8.843244  32.045495   8.942196   8.843244
# 3       01   200    french  12.694117  41.332906  12.455919  41.332906
# 4       02   200   english   7.587364   9.384005   9.176604   7.587364
# ..     ...   ...       ...        ...        ...        ...        ...
# 105     28   100    french  12.673169  12.740772        NaN  12.740772
# 106     29   100   english   8.287979  10.858998        NaN   8.287979
# 107     29   100    french  12.682820  12.929488        NaN  12.929488
# 108     30   100   english   8.025818   9.006159        NaN   8.025818
# 109     30   100    french  12.334501  11.864246        NaN  11.864246
#
#      different
# 0    31.985082
# 1    11.925142
# 2    32.045495
# 3    12.694117
# 4     9.384005
# ..         ...
# ...

# %%
boxplot = df_200_400h[['en_model', 'fr_model', 'bil_model', 'eval_lang']].boxplot(by='eval_lang', return_type='axes')
for bp in boxplot: 
    bp.set_ylabel('ABX error rate (in %)')
    bp.set_xlabel('Test Language')

# Here again just to show fundamental to look at it symmetrically as our test sets are not balancd (still looking into rules with XN)

# %%
boxplot = df_filt[['size','en_model', 'fr_model', 'bil_model',  'eval_lang']].boxplot(by='size', return_type='axes')
for bp in boxplot: 
    bp.set_ylabel('ABX error rate (in %)')
    bp.set_xlabel('# training hours')

# %%
boxplot = df[['size','en_model', 'fr_model', 'bil_model',  'eval_lang']].boxplot(by='size', return_type='axes')
for bp in boxplot: 
    bp.set_ylabel('ABX error rate (in %)')
    bp.set_xlabel('# training hours')

# %%
boxplot = df_filt[['size','en_model', 'fr_model', 'bil_model',  'eval_lang']].boxplot(by='size', return_type='axes')
for bp in boxplot: 
    bp.set_ylabel('ABX error rate (in %)')
    bp.set_xlabel('# training hours')

# %%
df_filt_size[['same', 'different', 'bil_model']].plot(marker="o")
# Out:
# <AxesSubplot:xlabel='size'>

# %%
df_filt_size[['en_model', 'fr_model', 'bil_model']].plot(marker="o")
# Out:
# <AxesSubplot:xlabel='size'>

# %%
df_filtered_size
# Out:
#        en_model   fr_model  bil_model       same  different
# size
# 100   11.411529  11.095609        NaN  10.771269  11.735870
# 200    9.754955  10.390571  10.388709   9.567031  10.578495
# 400    9.382971   9.951647   9.719597   9.087915  10.246703

# %%
df_size
# Out:
#        en_model   fr_model  bil_model       same  different
# size
# 100   12.059541  12.555682        NaN  11.915297  12.699926
# 200    9.831553  13.673777  10.377280  11.478840  12.026491
# 400    9.442970   9.916283   9.804259   9.124924  10.234329

# %%
#need to do it symmetrically (same vs different)
boxplot = df_200_400h[['same', 'different', 'bil_model','size']].boxplot(notch=False)
boxplot.set_ylabel('ABX error rate (in %)')
# need to find a way to compare bil 200h and same_100h and diff_100h
# here we are comparing total of 200h
# Out:
# Text(0, 0.5, 'ABX error rate (in %)')

# %%
#need to do it symmetrically (same vs different)
boxplot = df_200h[['same', 'different', 'bil_model','size']].boxplot(notch=False)
boxplot.set_ylabel('ABX error rate (in %)')
# need to find a way to compare bil 200h and same_100h and diff_100h
# here we are comparing total of 200h
# Out:
# Text(0, 0.5, 'ABX error rate (in %)')

# %%
#need to do it symmetrically (same vs different)
boxplot = df_400h[['same', 'different', 'bil_model']].boxplot(notch=True)
boxplot.set_ylabel('ABX error rate (in %)')
# need to find a way to compare bil 200h and same_100h and diff_100h
# here we are comparing total of 200h
# Out:
# Text(0, 0.5, 'ABX error rate (in %)')

# %%
df_200h.mean(numeric_only=True)
# Out:
# en_model      9.830602
# fr_model     13.672357
# bil_model    10.386968
# same         11.477921
# different    12.025038
# dtype: float64

# %%
df_400h.mean(numeric_only=True)
# Out:
# en_model      9.459676
# fr_model      9.915564
# bil_model     9.837628
# same          9.139567
# different    10.235673
# dtype: float64

# %%
np.mean([9.52668, 10.745492])
# Out:
# 10.136086

# %%
#check for 200h only
